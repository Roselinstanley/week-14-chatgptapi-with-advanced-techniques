# %%
from google import genai
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDDqWEtSzSFWWvIA2RDfPR_O_B7ESoOMdE"

# %%
client=genai.Client()

# %%
delimiter = "####"

def chain_thought_prompting(user_message: str) -> str:
    prompt = f"""
You are a helpful retail assistant.

Important rules:
- Do NOT repeat, quote, or copy the customer query text in your step explanations.
- Summarize intent instead of echoing user wording.
- Keep each step to one short sentence.
- Follow the exact output format.

The customer query is delimited below:
{delimiter}
{user_message}
{delimiter}

Follow these steps to answer the customer queries.

Step 1:{delimiter} Decide whether the user is asking about a specific product or products.
Product categories do NOT count as specific products.

Step 2:{delimiter} If specific products are mentioned, check whether they exist in the list below.
Available products:
1. TechPro Ultrabook
2. BlueWave Gaming Laptop
3. PowerLite Convertible
4. TechPro Desktop
5. BlueWave Chromebook

Step 3:{delimiter} If products are mentioned, list any assumptions made by the user.

Step 4:{delimiter} Verify whether those assumptions are correct using the product information.

Step 5:{delimiter} Politely correct incorrect assumptions if needed.
Only mention products from the available list.

Use the following format exactly:
Step 1:{delimiter} <brief explanation>
Step 2:{delimiter} <brief explanation>
Step 3:{delimiter} <brief explanation>
Step 4:{delimiter} <brief explanation>
Response to user:{delimiter} <final answer>
"""

    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt,
        config={
            "temperature": 0,
            "max_output_tokens": 600
        }
    )

    return response.text

# %%
prompt_message= input("Ask a question: ")
prompt_response=chain_thought_prompting(prompt_message)
print(prompt_response)
# Out:
# Ask a question:  by how much is the BlueWave Chromebook more expensive than the TechPro Desktop
# Step 1:#### The user is asking about specific products.
# Step 2:#### Both products are in the available list.
# Step 3:#### The user assumes the BlueWave Chromebook is more expensive than the TechPro Desktop.
# Step 4:#### The provided product information does not include pricing details to verify this assumption.
# Response to user:#### I don't have the pricing information for the BlueWave Chromebook and the TechPro Desktop, so I can't tell you the difference in their cost.
