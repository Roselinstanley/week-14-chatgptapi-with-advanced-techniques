# %%
#pip install gradio

# %%
from google import genai
import gradio as gr
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDhE56LDoInWCyoLeA8_qxkCBGatgazmXs"

# %%
client=genai.Client()
messages=[]
system_msg="Your chef assistant is ready"
messages.append(system_msg)

# %%
def customGeminigpt(prompt_msg):
    chat_response=client.models.generate_content(model="gemini-2.5-flash",
                                                 contents=prompt_msg)
    text=chat_response.candidates[0].content.parts[0].text
    messages.append(text)    
    return(text)    
gr.Interface(fn=customGeminigpt,inputs="text",outputs="text",title="Iam your chef").launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * Running on public URL: https://3b693c92c8d8e77949.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3b693c92c8d8e77949.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
