# %%
from google import genai
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDxCGsFgDCJLVNLjcOtj4_VS4nVpKSpFvA"

# %%
client=genai.Client()

# %%
def get_inputclassification(messages):
    classification_prompt=f"""
    You are a support ticket classifier.

Classify the user's message into:
1. One PRIMARY category
2. One SECONDARY category

Primary categories (choose only one):
- Billing
- Technical Support
- Account Management
- General Enquiry

Secondary categories:

Billing:
- Payment Failure
- Invoice Request
- Refund & Cancellation
- Pricing & Plans
- Billing History

Technical Support:
- API Errors
- Integration Issues
- Performance Issues
- Bug Report
- Configuration & Setup

Account Management:
- Login Issues
- Account Creation
- Profile Updates
- Access & Permissions
- Account Deletion

General Enquiry:
- Product Information
- Documentation Help
- Use Case Guidance
- Sales & Partnerships
- Other / Unclear

Rules:
- Choose the best matching categories only
- Do NOT invent new categories
- If unsure, select "General Enquiry" → "Other / Unclear"
- Return JSON only

Json format:
{{
    "Primary Category":""
    "Secondary Category":""
    "confidence":0.0
}}
User message:
\"\"\"{messages}\"\"\"
"""
    prompt_response=client.models.generate_content(model="gemini-2.5-flash",
                                                   contents=classification_prompt,
                                                  config={
                                                            "temperature": 0,
                                                            "max_output_tokens": 300
                                                    })
    prompt_response_content=prompt_response.text
    return prompt_response_content

# %%
messages=input("Enter your Query")
prompt_response=get_inputclassification(messages)
print(prompt_response)
# Out:
# Enter your Query iam getting 404 error
# ```json
# {
#     "Primary Category": "Technical Support",
#     "Secondary Category": "API Errors",
#     "confidence": 0.9
# }
# ```
