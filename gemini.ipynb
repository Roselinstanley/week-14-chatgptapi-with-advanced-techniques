# %%
#pip install -U google-genai

# %%
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDhE56LDoInWCyoLeA8_qxkCBGatgazmXs"

# %%
from google import genai

# %%
client=genai.Client()

# %%
chatmodel=client.models.generate_content(model="gemini-2.5-flash",
                                        contents="Give me 3 ideas with apps I could build with gemini api")

# %%
print(chatmodel.text)
# Out:
# Here are 3 app ideas you could build using the Gemini API, leveraging its multimodal capabilities and advanced reasoning:
#
# ---
#
# ### 1. MuseLens: The Visual Story Weaver
#
# **Core Concept:** An app that transforms images into rich narrative prompts, character ideas, or even short stories, helping creative writers overcome writer's block or explore new angles.
#
# **How Gemini API is Used:**
# *   **Multimodal Input (`gemini-pro-vision`):** Users upload an image (e.g., a photo of an old house, a bustling city street, a mysterious landscape). Gemini analyzes the image, identifying objects, settings, moods, and potential implied narratives.
# *   **Generative Text (`gemini-pro`):** Based on the image analysis, Gemini generates:
#     *   **Creative Prompts:** "What secret lies behind that locked door?" "Who are the last two people to have seen this view?"
#     *   **Character Sketches:** Descriptions of potential inhabitants or visitors to the scene.
# ...
