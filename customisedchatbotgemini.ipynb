# %%
from google import genai

# %%
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDhE56LDoInWCyoLeA8_qxkCBGatgazmXs"

# %%
client=genai.Client()

# %%
messages=[]
system_msg=input("What kind of chatbot would you like to create")
messages.append(system_msg)
print("Your new virtual assistant is ready")
while True:
    prompt_msg=input()
    messages.append(prompt_msg)
    if prompt_msg=="quit":
        print("Good Bye")
        break
    gemini_response=client.models.generate_content(model="gemini-2.5-flash",
    contents=messages)
    text=gemini_response.candidates[0].content.parts[0].text
    messages.append(text)
    print("\n",text,"\n")
# Out:
# What kind of chatbot would you like to create sports bot
# Your new virtual assistant is ready
#  tennis
#  Ah, tennis! A fantastic sport.
#
# What about tennis would you like to discuss? I can talk about:
#
# *   **Current players and their performance** (e.g., Djokovic, Swiatek, Alcaraz, Sabalenka, Gauff)
# *   **Major tournaments** (Grand Slams: Australian Open, French Open, Wimbledon, US Open)
# *   **Rules and scoring**
# *   **History of the sport**
# *   **Playing tips or equipment**
# *   **Recent news or matches**
#
# Just let me know what's on your mind!
#  rules and scoring
#  Okay, let's break down the rules and scoring of tennis! It can seem a little unique at first, but once you get the hang of it, it's quite logical.
#
# ### The Objective
#
# ...
