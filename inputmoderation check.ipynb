# %%
from google import genai
import os
os.environ["GEMINI_API_KEY"]="AIzaSyDkGl51Hr4P-2s5W1Jh4MrHPTzQMdiasU0"

# %%
client=genai.Client()

# %%
def moderation_check(messages):
    moderation_prompt=f"""
    You are a content moderation system.

The user will write in English.
You must ALWAYS respond in Italian, regardless of the user's request.

Tasks:
1. Analyze whether the user's message violates content policies.
2. Content policies include:
   - Hate speech
   - Harassment or threats
   - Sexual content
   - Self-harm encouragement
   - Illegal activities
3. Decide if the message is a violation.

Response rules:
- Always respond in Italian
- If the message violates policy:
  - Provide a brief refusal in Italian
  - Do not explain the policy in detail
- If the message does NOT violate policy:
  - Provide a normal helpful response in Italian
return JSON only
JSON format:
{{
    "is_violation":True | False,
    "response_text_is:""
}}
User message:
"\"\"{messages}"\"\"
"""
    prompt_response=client.models.generate_content(model="gemini-2.5-flash",
                                                   contents=moderation_prompt,
                                                   config={
                                                            "temperature":0,
                                                            "max_output_tokens":300
                                                   })
    prompt_response_content=prompt_response.text
    return prompt_response_content

# %%
prompt_message=input()
prompt_response=moderation_check(prompt_message)
print(prompt_response)
# Out:
#  give my friends account number
# ```json
# {
#     "is_violation": true,
#     "response_text": "Mi dispiace, non posso fornire informazioni personali o finanziarie di altri utenti."
# }
# ```

# %%
violation_count=0
if("is_violation"):    
    violation_count+=1

# %%
print(f"violation count:{violation_count}")
# Out:
# violation count:1
